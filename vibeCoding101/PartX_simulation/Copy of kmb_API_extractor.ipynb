# %%
"""
Simple KMB API Data Extractor

Extracts real-time bus arrival data from KMB API for specified stop IDs.
"""

import requests
import json
from datetime import datetime, timedelta
import pandas as pd


def get_kmb_data(stop_id):
    """
    Extract API data from KMB for a given stop ID.

    Args:
        stop_id (str): The stop ID to query

    Returns:
        dict: API response data or None if error
    """
    url = f"https://data.etabus.gov.hk/v1/transport/kmb/stop-eta/{stop_id}"

    try:
        print(f"Fetching data for stop ID: {stop_id}")
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()

        print(f"Successfully retrieved data for stop {stop_id}")
        return data

    except requests.RequestException as e:
        print(f"Error fetching data for stop {stop_id}: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON for stop {stop_id}: {e}")
        return None


def process_data(data, stop_id):
    """
    Process the raw API data to extract useful information.

    Args:
        data (dict): Raw API response
        stop_id (str): Stop ID for reference

    Returns:
        list: Processed route data
    """
    if not data or not data.get('data'):
        print(f"No data available for stop {stop_id}")
        return []

    routes = data['data']
    processed_routes = []

    # Get current time for filtering
    now = datetime.now()

    print(f"\nProcessing {len(routes)} route entries for stop {stop_id}:")

    for route in routes:
        route_info = {
            'stop_id': stop_id,
            'route': route.get('route', 'Unknown'),
            'direction': route.get('dir', 'Unknown'),
            'eta': route.get('eta', 'No ETA'),
            'eta_seq': route.get('eta_seq', 'N/A'),
            'data_timestamp': route.get('data_timestamp', 'N/A')
        }

        processed_routes.append(route_info)

        # Print route info
        eta_str = route_info['eta'] if route_info['eta'] != 'No ETA' else 'No ETA'
        print(f"  Route {route_info['route']} ({route_info['direction']}): {eta_str}")

    return processed_routes


def main():
    """Main function to extract data for all stop IDs."""

    # Stop IDs from your stations dictionary
    stations = {
        "St. Martin": [
            "3F24CFF9046300D9",
            "33ABA49F0E91A247",
            "07AB149DAD888683",
            "4A0ECA0D5AA4CB7E"
        ],
        "CHONG SAN ROAD": [
            "3A7AC3A5F9530786",
            "023E9E5A9E073E1A",
            "B34F59A0270AEDA4",
            "437CE05BCFE6248C"
        ]
    }

    all_data = []

    print("KMB API Data Extractor")
    print("=" * 50)

    for station_name, stop_ids in stations.items():
        print(f"\n{'='*20} {station_name} {'='*20}")

        for stop_id in stop_ids:
            # Get raw data from API
            raw_data = get_kmb_data(stop_id)

            if raw_data:
                # Process the data
                processed_data = process_data(raw_data, stop_id)
                all_data.extend(processed_data)
            else:
                print(f"Failed to get data for stop {stop_id}")

    # Save to CSV
    if all_data:
        df = pd.DataFrame(all_data)
        filename = f"kmb_data_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        df.to_csv(filename, index=False)
        print(f"\n{'='*50}")
        print(f"Data extraction complete!")
        print(f"Total records: {len(all_data)}")
        print(f"Data saved to: {filename}")

        # Display summary
        print(f"\nSummary:")
        print(f"Total routes found: {len(all_data)}")

        # Group by station
        df['station'] = df['stop_id'].map({
            stop_id: station for station, stops in stations.items()
            for stop_id in stops
        })

        station_summary = df.groupby('station').size()
        print(f"\nRoutes per station:")
        for station, count in station_summary.items():
            print(f"  {station}: {count} routes")

    else:
        print("No data extracted. Please check your internet connection.")


if __name__ == "__main__":
    main()
# Out:
# KMB API Data Extractor
# ==================================================
#
# ==================== St. Martin ====================
# Fetching data for stop ID: 3F24CFF9046300D9
# Successfully retrieved data for stop 3F24CFF9046300D9
#
# Processing 15 route entries for stop 3F24CFF9046300D9:
#   Route 272A (O): 2025-10-19T18:49:44+08:00
#   Route 272A (O): 2025-10-19T19:03:39+08:00
#   Route 272A (O): 2025-10-19T19:18:03+08:00
#   Route 272A (O): 2025-10-19T18:49:44+08:00
#   Route 272A (O): 2025-10-19T19:03:39+08:00
#   Route 272A (O): 2025-10-19T19:18:03+08:00
#   Route 272A (O): 2025-10-19T18:49:44+08:00
#   Route 272A (O): 2025-10-19T19:03:39+08:00
#   Route 272A (O): 2025-10-19T19:18:03+08:00
#   Route 274 (O): None
#   Route 274P (I): 2025-10-19T19:05:31+08:00
#   Route 274P (I): 2025-10-19T19:24:33+08:00
#   Route 64X (O): None
#   Route 65X (O): None
#   Route 82D (O): None
# Fetching data for stop ID: 33ABA49F0E91A247
# Successfully retrieved data for stop 33ABA49F0E91A247
#
# Processing 8 route entries for stop 33ABA49F0E91A247:
#   Route 263C (I): None
#   Route 272P (O): None
#   Route 272P (O): None
#   Route 272X (O): None
#   Route 73D (I): None
#   Route 900 (O): None
#   Route 900X (O): None
#   Route 907D (O): None
# Fetching data for stop ID: 07AB149DAD888683
# Successfully retrieved data for stop 07AB149DAD888683
#
# Processing 5 route entries for stop 07AB149DAD888683:
#   Route 271B (O): None
#   Route 74 (O): None
#   Route 74D (O): 2025-10-19T19:25:17+08:00
#   Route 74P (I): None
#   Route 96 (I): 2025-10-19T19:00:11+08:00
# Fetching data for stop ID: 4A0ECA0D5AA4CB7E
# Successfully retrieved data for stop 4A0ECA0D5AA4CB7E
#
# Processing 3 route entries for stop 4A0ECA0D5AA4CB7E:
#   Route A47X (O): None
#   Route A47X (O): None
#   Route NA47 (O): None
#
# ==================== CHONG SAN ROAD ====================
# Fetching data for stop ID: 3A7AC3A5F9530786
# Successfully retrieved data for stop 3A7AC3A5F9530786
#
# Processing 9 route entries for stop 3A7AC3A5F9530786:
#   Route 271B (O): None
#   Route 274 (O): None
#   Route 64X (O): None
#   Route 65X (O): None
#   Route 74 (O): None
#   Route 74D (O): 2025-10-19T19:26:20+08:00
#   Route 74P (I): None
#   Route 82D (O): None
#   Route 96 (I): 2025-10-19T19:01:01+08:00
# Fetching data for stop ID: 023E9E5A9E073E1A
# Successfully retrieved data for stop 023E9E5A9E073E1A
#
# Processing 8 route entries for stop 023E9E5A9E073E1A:
#   Route 263C (I): None
#   Route 272P (O): None
#   Route 272P (O): None
#   Route 272X (O): None
#   Route 73D (I): None
#   Route 900 (O): None
#   Route 900X (O): None
#   Route 907D (O): None
# Fetching data for stop ID: B34F59A0270AEDA4
# Successfully retrieved data for stop B34F59A0270AEDA4
#
# Processing 11 route entries for stop B34F59A0270AEDA4:
#   Route 272A (O): 2025-10-19T18:50:50+08:00
#   Route 272A (O): 2025-10-19T19:04:43+08:00
#   Route 272A (O): 2025-10-19T19:19:07+08:00
#   Route 272A (O): 2025-10-19T18:50:50+08:00
#   Route 272A (O): 2025-10-19T19:04:43+08:00
#   Route 272A (O): 2025-10-19T19:19:07+08:00
#   Route 272A (O): 2025-10-19T18:50:50+08:00
#   Route 272A (O): 2025-10-19T19:04:43+08:00
#   Route 272A (O): 2025-10-19T19:19:07+08:00
#   Route 274P (I): 2025-10-19T19:06:34+08:00
#   Route 274P (I): 2025-10-19T19:25:35+08:00
# Fetching data for stop ID: 437CE05BCFE6248C
# Successfully retrieved data for stop 437CE05BCFE6248C
#
# Processing 3 route entries for stop 437CE05BCFE6248C:
#   Route A47X (O): None
#   Route A47X (O): None
#   Route NA47 (O): None
#
# ==================================================
# Data extraction complete!
# Total records: 62
# Data saved to: kmb_data_20251019_105021.csv
#
# Summary:
# Total routes found: 62
#
# Routes per station:
#   CHONG SAN ROAD: 31 routes
#   St. Martin: 31 routes

# %%
import requests
import json
from datetime import datetime, timedelta
import pandas as pd


def get_kmb_data(stop_id):
    """
    Extract API data from KMB for a given stop ID.

    Args:
        stop_id (str): The stop ID to query

    Returns:
        dict: API response data or None if error
    """
    url = f"https://data.etabus.gov.hk/v1/transport/kmb/stop-eta/{stop_id}"

    try:
        print(f"Fetching data for stop ID: {stop_id}")
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()

        print(f"Successfully retrieved data for stop {stop_id}")
        return data

    except requests.RequestException as e:
        print(f"Error fetching data for stop {stop_id}: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON for stop {stop_id}: {e}")
        return None


def process_data(data, stop_id):
    """
    Process the raw API data to extract useful information.

    Args:
        data (dict): Raw API response
        stop_id (str): Stop ID for reference

    Returns:
        list: Processed route data
    """
    if not data or not data.get('data'):
        print(f"No data available for stop {stop_id}")
        return []

    routes = data['data']
    processed_routes = []

    # Get current time for filtering
    now = datetime.now()

    print(f"\nProcessing {len(routes)} route entries for stop {stop_id}:")

    for route in routes:
        route_info = {
            'stop_id': stop_id,
            'route': route.get('route', 'Unknown'),
            'direction': route.get('dir', 'Unknown'),
            'eta': route.get('eta', 'No ETA'),
            'eta_seq': route.get('eta_seq', 'N/A'),
            'data_timestamp': route.get('data_timestamp', 'N/A')
        }

        processed_routes.append(route_info)

        # Print route info
        eta_str = route_info['eta'] if route_info['eta'] != 'No ETA' else 'No ETA'
        print(f"  Route {route_info['route']} ({route_info['direction']}): {eta_str}")

    return processed_routes


def main():
    """Main function to extract data for all stop IDs."""

    # Stop IDs from your stations dictionary
    stations = {
        "St. Martin": [
            "3F24CFF9046300D9",
            "33ABA49F0E91A247",
            "07AB149DAD888683",
            "4A0ECA0D5AA4CB7E"
        ],
        "CHONG SAN ROAD": [
            "3A7AC3A5F9530786",
            "023E9E5A9E073E1A",
            "B34F59A0270AEDA4",
            "437CE05BCFE6248C"
        ]
    }

    all_data = []

    print("KMB API Data Extractor")
    print("=" * 50)

    for station_name, stop_ids in stations.items():
        print(f"\n{'='*20} {station_name} {'='*20}")

        for stop_id in stop_ids:
            # Get raw data from API
            raw_data = get_kmb_data(stop_id)

            if raw_data:
                # Process the data
                processed_data = process_data(raw_data, stop_id)
                all_data.extend(processed_data)
            else:
                print(f"Failed to get data for stop {stop_id}")

    # Save to CSV
    if all_data:
        df = pd.DataFrame(all_data)
        filename = f"kmb_data_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        df.to_csv(filename, index=False)
        print(f"\n{'='*50}")
        print(f"Data extraction complete!")
        print(f"Total records: {len(all_data)}")
        print(f"Data saved to: {filename}")

        # Display summary
        print(f"\nSummary:")
        print(f"Total routes found: {len(all_data)}")

        # Group by station
        df['station'] = df['stop_id'].map({
            stop_id: station for station, stops in stations.items()
            for stop_id in stops
        })

        station_summary = df.groupby('station').size()
        print(f"\nRoutes per station:")
        for station, count in station_summary.items():
            print(f"  {station}: {count} routes")

    else:
        print("No data extracted. Please check your internet connection.")


if __name__ == "__main__":
    main()
# Out:
# KMB API Data Extractor
# ==================================================
#
# ==================== St. Martin ====================
# Fetching data for stop ID: 3F24CFF9046300D9
# Successfully retrieved data for stop 3F24CFF9046300D9
#
# Processing 14 route entries for stop 3F24CFF9046300D9:
#   Route 272A (O): 2025-11-04T13:52:13+08:00
#   Route 272A (O): 2025-11-04T14:05:04+08:00
#   Route 272A (O): 2025-11-04T14:17:00+08:00
#   Route 272A (O): 2025-11-04T13:52:13+08:00
#   Route 272A (O): 2025-11-04T14:05:04+08:00
#   Route 272A (O): 2025-11-04T14:17:00+08:00
#   Route 272A (O): 2025-11-04T13:52:13+08:00
#   Route 272A (O): 2025-11-04T14:05:04+08:00
#   Route 272A (O): 2025-11-04T14:17:00+08:00
#   Route 274 (O): None
#   Route 274P (I): None
#   Route 64X (O): None
#   Route 65X (O): None
#   Route 82D (O): None
# Fetching data for stop ID: 33ABA49F0E91A247
# Successfully retrieved data for stop 33ABA49F0E91A247
#
# Processing 9 route entries for stop 33ABA49F0E91A247:
#   Route 263C (I): None
#   Route 272P (O): None
#   Route 272P (O): None
#   Route 272X (O): 2025-11-04T13:55:00+08:00
#   Route 272X (O): 2025-11-04T14:25:57+08:00
#   Route 73D (I): None
#   Route 900 (O): None
#   Route 900X (O): None
#   Route 907D (O): None
# Fetching data for stop ID: 07AB149DAD888683
# Successfully retrieved data for stop 07AB149DAD888683
#
# Processing 5 route entries for stop 07AB149DAD888683:
#   Route 271B (O): None
#   Route 74 (O): None
#   Route 74D (O): 2025-11-04T14:26:05+08:00
#   Route 74P (I): None
#   Route 96 (I): None
# Fetching data for stop ID: 4A0ECA0D5AA4CB7E
# Successfully retrieved data for stop 4A0ECA0D5AA4CB7E
#
# Processing 3 route entries for stop 4A0ECA0D5AA4CB7E:
#   Route A47X (O): None
#   Route A47X (O): None
#   Route NA47 (O): None
#
# ==================== CHONG SAN ROAD ====================
# Fetching data for stop ID: 3A7AC3A5F9530786
# Successfully retrieved data for stop 3A7AC3A5F9530786
#
# Processing 5 route entries for stop 3A7AC3A5F9530786:
#   Route 271B (O): None
#   Route 74 (O): None
#   Route 74D (O): 2025-11-04T14:27:11+08:00
#   Route 74P (I): None
#   Route 96 (I): None
# Fetching data for stop ID: 023E9E5A9E073E1A
# Successfully retrieved data for stop 023E9E5A9E073E1A
#
# Processing 9 route entries for stop 023E9E5A9E073E1A:
#   Route 263C (I): None
#   Route 272P (O): None
#   Route 272P (O): None
#   Route 272X (O): 2025-11-04T13:56:07+08:00
#   Route 272X (O): 2025-11-04T14:27:00+08:00
#   Route 73D (I): None
#   Route 900 (O): None
#   Route 900X (O): None
#   Route 907D (O): None
# Fetching data for stop ID: B34F59A0270AEDA4
# Successfully retrieved data for stop B34F59A0270AEDA4
#
# Processing 14 route entries for stop B34F59A0270AEDA4:
#   Route 272A (O): 2025-11-04T13:53:25+08:00
#   Route 272A (O): 2025-11-04T14:06:18+08:00
#   Route 272A (O): 2025-11-04T14:18:11+08:00
#   Route 272A (O): 2025-11-04T13:53:25+08:00
#   Route 272A (O): 2025-11-04T14:06:18+08:00
#   Route 272A (O): 2025-11-04T14:18:11+08:00
#   Route 272A (O): 2025-11-04T13:53:25+08:00
#   Route 272A (O): 2025-11-04T14:06:18+08:00
#   Route 272A (O): 2025-11-04T14:18:11+08:00
#   Route 274 (O): None
#   Route 274P (I): None
#   Route 64X (O): None
#   Route 65X (O): None
#   Route 82D (O): None
# Fetching data for stop ID: 437CE05BCFE6248C
# Successfully retrieved data for stop 437CE05BCFE6248C
#
# Processing 3 route entries for stop 437CE05BCFE6248C:
#   Route A47X (O): None
#   Route A47X (O): None
#   Route NA47 (O): None
#
# ==================================================
# Data extraction complete!
# Total records: 62
# Data saved to: kmb_data_20251104_054645.csv
#
# Summary:
# Total routes found: 62
#
# Routes per station:
#   CHONG SAN ROAD: 31 routes
#   St. Martin: 31 routes

# %%
import requests
import json
from datetime import datetime

def debug_bus_stops():
    # Your stop IDs
    stops = {
        "St. Martin": "3F24CFF9046300D9",
        "CHONG SAN ROAD": "B34F59A0270AEDA4"
    }
    
    # Both API providers
    providers = {
        "KMB": "https://data.etabus.gov.hk/v1/transport/kmb/stop-eta/",
        "Citybus/NWFB": "https://rt.data.gov.hk/v1/transport/citybus-nwfb/stop-eta/"
    }
    
    for stop_name, stop_id in stops.items():
        print(f"\n{'='*60}")
        print(f"DEBUGGING: {stop_name} (ID: {stop_id})")
        print(f"Time: {datetime.now()}")
        print(f"{'='*60}")
        
        found_data = False
        
        for provider_name, base_url in providers.items():
            url = f"{base_url}{stop_id}"
            print(f"\nTrying {provider_name} API:")
            print(f"URL: {url}")
            
            try:
                response = requests.get(url, timeout=10)
                print(f"HTTP Status: {response.status_code}")
                
                if response.status_code == 200:
                    data = response.json()
                    
                    if 'data' in data and data['data']:
                        routes_with_eta = []
                        routes_without_eta = []
                        
                        for route_data in data['data']:
                            route_info = {
                                'route': route_data.get('route', 'N/A'),
                                'eta': route_data.get('eta'),
                                'dir': route_data.get('dir', 'N/A'),
                                'dest_tc': route_data.get('dest_tc', 'N/A'),
                                'service_type': route_data.get('service_type', 'N/A')
                            }
                            
                            if route_data.get('eta'):
                                routes_with_eta.append(route_info)
                            else:
                                routes_without_eta.append(route_info)
                        
                        print(f"✓ Found {len(routes_with_eta)} routes WITH ETA data")
                        print(f"✗ Found {len(routes_without_eta)} routes WITHOUT ETA data")
                        
                        if routes_with_eta:
                            found_data = True
                            print("\nRoutes WITH ETA:")
                            for route in routes_with_eta[:5]:  # Show first 5
                                print(f"  - {route['route']} (Dir: {route['dir']}) -> {route['eta']}")
                        
                        if routes_without_eta:
                            print("\nRoutes WITHOUT ETA (sample):")
                            for route in routes_without_eta[:3]:
                                print(f"  - {route['route']} (Dir: {route['dir']}) -> NULL")
                    
                    else:
                        print("No route data found in response")
                        
                else:
                    print(f"API returned non-200 status")
                    
            except Exception as e:
                print(f"Error calling API: {e}")
        
        if not found_data:
            print(f"\n❌ No ETA data found for {stop_name} with any provider")
        else:
            print(f"\n✅ ETA data found for {stop_name}")

# Run the debugger
debug_bus_stops()
# Out:
# ============================================================
# DEBUGGING: St. Martin (ID: 3F24CFF9046300D9)
# Time: 2025-11-05 05:48:25.993746
# ============================================================
#
# Trying KMB API:
# URL: https://data.etabus.gov.hk/v1/transport/kmb/stop-eta/3F24CFF9046300D9
# HTTP Status: 200
# ✓ Found 9 routes WITH ETA data
# ✗ Found 5 routes WITHOUT ETA data
#
# Routes WITH ETA:
#   - 272A (Dir: O) -> 2025-11-05T13:53:04+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:04:52+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:17:02+08:00
#   - 272A (Dir: O) -> 2025-11-05T13:53:04+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:04:52+08:00
#
# Routes WITHOUT ETA (sample):
#   - 274 (Dir: O) -> NULL
#   - 274P (Dir: I) -> NULL
#   - 64X (Dir: O) -> NULL
#
# Trying Citybus/NWFB API:
# URL: https://rt.data.gov.hk/v1/transport/citybus-nwfb/stop-eta/3F24CFF9046300D9
# HTTP Status: 422
# API returned non-200 status
#
# ✅ ETA data found for St. Martin
#
# ============================================================
# DEBUGGING: CHONG SAN ROAD (ID: B34F59A0270AEDA4)
# Time: 2025-11-05 05:48:26.259698
# ============================================================
#
# Trying KMB API:
# URL: https://data.etabus.gov.hk/v1/transport/kmb/stop-eta/B34F59A0270AEDA4
# HTTP Status: 200
# ✓ Found 9 routes WITH ETA data
# ✗ Found 5 routes WITHOUT ETA data
#
# Routes WITH ETA:
#   - 272A (Dir: O) -> 2025-11-05T13:54:22+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:06:10+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:18:16+08:00
#   - 272A (Dir: O) -> 2025-11-05T13:54:22+08:00
#   - 272A (Dir: O) -> 2025-11-05T14:06:10+08:00
#
# Routes WITHOUT ETA (sample):
#   - 274 (Dir: O) -> NULL
#   - 274P (Dir: I) -> NULL
#   - 64X (Dir: O) -> NULL
#
# Trying Citybus/NWFB API:
# URL: https://rt.data.gov.hk/v1/transport/citybus-nwfb/stop-eta/B34F59A0270AEDA4
# HTTP Status: 422
# API returned non-200 status
#
# ✅ ETA data found for CHONG SAN ROAD
